# %% [markdown]
# <a href="https://colab.research.google.com/github/SilentClaw27/AdvancedRL/blob/main/lander_reinforce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# apt-get install swig
#
# git clone https://github.com/pybox2d/pybox2d
# cd pybox2d
# python setup.py build
# python setup.py install
#
# apt-get install -y xvfb
#
# pip install \
#   gym==0.21\
#   gym[box2d]==0.21\
#   pyvirtualdisplay\
#   pyglet==1.5.27 \
#   colabgymrender
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   swig3.0
# Suggested packages:
#   swig-doc swig-examples swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig swig3.0
# 0 upgraded, 2 newly installed, 0 to remove and 20 not upgraded.
# Need to get 1,100 kB of archives.
# After this operation, 5,822 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig3.0 amd64 3.0.12-1 [1,094 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig amd64 3.0.12-1 [6,460 B]
# Fetched 1,100 kB in 0s (2,602 kB/s)
# Selecting previously unselected package swig3.0.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../swig3.0_3.0.12-1_amd64.deb ...
# Unpacking swig3.0 (3.0.12-1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_3.0.12-1_amd64.deb ...
# Unpacking swig (3.0.12-1) ...
# Setting up swig3.0 (3.0.12-1) ...
# Setting up swig (3.0.12-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# ['Box2D', 'Box2D.examples', 'Box2D.b2', 'Box2D.tests', 'Box2D.examples.simple', 'Box2D.examples.backends', 'Box2D.examples.opencv', 'Box2D.examples.pgu', 'Box2D.examples.pgu.gui']
# running build
# running build_py
# running build_ext
# building 'Box2D._Box2D' extension
# swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
# swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
# creating build
# creating build/temp.linux-x86_64-3.8
# creating build/temp.linux-x86_64-3.8/Box2D
# creating build/temp.linux-x86_64-3.8/Box2D/Dynamics
# creating build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts
# creating build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints
# creating build/temp.linux-x86_64-3.8/Box2D/Common
# creating build/temp.linux-x86_64-3.8/Box2D/Collision
# creating build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Box2D_wrap.cpp -o build/temp.linux-x86_64-3.8/Box2D/Box2D_wrap.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/b2Body.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2Body.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/b2Island.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2Island.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/b2World.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2World.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/b2Fixture.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2Fixture.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/b2WorldCallbacks.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2WorldCallbacks.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/b2ContactManager.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2ContactManager.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2CircleContact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2CircleContact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2Contact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2Contact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2PolygonAndCircleContact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2PolygonAndCircleContact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2EdgeAndCircleContact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2EdgeAndCircleContact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2EdgeAndPolygonContact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2EdgeAndPolygonContact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2ContactSolver.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2ContactSolver.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2PolygonContact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2PolygonContact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2ChainAndCircleContact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2ChainAndCircleContact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Contacts/b2ChainAndPolygonContact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2ChainAndPolygonContact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2FrictionJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2FrictionJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2RopeJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2RopeJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2DistanceJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2DistanceJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2WheelJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2WheelJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2PrismaticJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2PrismaticJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2Joint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2Joint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2WeldJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2WeldJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2MotorJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2MotorJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2RevoluteJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2RevoluteJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2GearJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2GearJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2MouseJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2MouseJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Dynamics/Joints/b2PulleyJoint.cpp -o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2PulleyJoint.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Common/b2Timer.cpp -o build/temp.linux-x86_64-3.8/Box2D/Common/b2Timer.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Common/b2Draw.cpp -o build/temp.linux-x86_64-3.8/Box2D/Common/b2Draw.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Common/b2Math.cpp -o build/temp.linux-x86_64-3.8/Box2D/Common/b2Math.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Common/b2StackAllocator.cpp -o build/temp.linux-x86_64-3.8/Box2D/Common/b2StackAllocator.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Common/b2Settings.cpp -o build/temp.linux-x86_64-3.8/Box2D/Common/b2Settings.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Common/b2BlockAllocator.cpp -o build/temp.linux-x86_64-3.8/Box2D/Common/b2BlockAllocator.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/b2CollidePolygon.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/b2CollidePolygon.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/b2BroadPhase.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/b2BroadPhase.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/b2Distance.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/b2Distance.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/b2DynamicTree.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/b2DynamicTree.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/b2TimeOfImpact.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/b2TimeOfImpact.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/b2CollideEdge.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/b2CollideEdge.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/b2Collision.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/b2Collision.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/b2CollideCircle.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/b2CollideCircle.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/Shapes/b2EdgeShape.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes/b2EdgeShape.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/Shapes/b2PolygonShape.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes/b2PolygonShape.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/Shapes/b2CircleShape.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes/b2CircleShape.o -I. -Wno-unused
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.8 -c Box2D/Collision/Shapes/b2ChainShape.cpp -o build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes/b2ChainShape.o -I. -Wno-unused
# creating build/lib.linux-x86_64-3.8
# creating build/lib.linux-x86_64-3.8/Box2D
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.8/Box2D/Box2D_wrap.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2Body.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2Island.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2World.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2Fixture.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2WorldCallbacks.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/b2ContactManager.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2CircleContact.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2Contact.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2PolygonAndCircleContact.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2EdgeAndCircleContact.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2EdgeAndPolygonContact.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2ContactSolver.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2PolygonContact.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2ChainAndCircleContact.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Contacts/b2ChainAndPolygonContact.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2FrictionJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2RopeJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2DistanceJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2WheelJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2PrismaticJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2Joint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2WeldJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2MotorJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2RevoluteJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2GearJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2MouseJoint.o build/temp.linux-x86_64-3.8/Box2D/Dynamics/Joints/b2PulleyJoint.o build/temp.linux-x86_64-3.8/Box2D/Common/b2Timer.o build/temp.linux-x86_64-3.8/Box2D/Common/b2Draw.o build/temp.linux-x86_64-3.8/Box2D/Common/b2Math.o build/temp.linux-x86_64-3.8/Box2D/Common/b2StackAllocator.o build/temp.linux-x86_64-3.8/Box2D/Common/b2Settings.o build/temp.linux-x86_64-3.8/Box2D/Common/b2BlockAllocator.o build/temp.linux-x86_64-3.8/Box2D/Collision/b2CollidePolygon.o build/temp.linux-x86_64-3.8/Box2D/Collision/b2BroadPhase.o build/temp.linux-x86_64-3.8/Box2D/Collision/b2Distance.o build/temp.linux-x86_64-3.8/Box2D/Collision/b2DynamicTree.o build/temp.linux-x86_64-3.8/Box2D/Collision/b2TimeOfImpact.o build/temp.linux-x86_64-3.8/Box2D/Collision/b2CollideEdge.o build/temp.linux-x86_64-3.8/Box2D/Collision/b2Collision.o build/temp.linux-x86_64-3.8/Box2D/Collision/b2CollideCircle.o build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes/b2EdgeShape.o build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes/b2PolygonShape.o build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes/b2CircleShape.o build/temp.linux-x86_64-3.8/Box2D/Collision/Shapes/b2ChainShape.o -o build/lib.linux-x86_64-3.8/Box2D/_Box2D.cpython-38-x86_64-linux-gnu.so
# copying library/Box2D/__init__.py -> build/lib.linux-x86_64-3.8/Box2D
# copying library/Box2D/Box2D.py -> build/lib.linux-x86_64-3.8/Box2D
# creating build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/conveyor_belt.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/restitution.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/bullet.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/pinball.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/box_cutter.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/simple_cv.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/web.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/apply_force.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/cantilever.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/vertical_stack.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/rope.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/__init__.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/tumbler.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/character_collision.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/bridge.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/collision_filtering.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/collision_processing.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/theo_jansen.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/car.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/mobile.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/framework.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/hello.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/top_down_car.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/edge_shapes.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/tiles.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/body_types.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/edge_test.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/confined.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/liquid.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/settings.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/empty.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/time_of_impact.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/pyramid.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/motor_joint.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/breakable.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/cloth.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/chain.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/raycast.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/pulley.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/convex_hull.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/gish_tribute.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/distance.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# copying library/Box2D/examples/one_sided_platform.py -> build/lib.linux-x86_64-3.8/Box2D/examples
# creating build/lib.linux-x86_64-3.8/Box2D/b2
# copying library/Box2D/b2/__init__.py -> build/lib.linux-x86_64-3.8/Box2D/b2
# creating build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/basics.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_matrix.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_world.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_color.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_contact_listener.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_vector.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/__init__.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_body.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_joints.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_kwargs.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_edgechain.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# copying library/Box2D/tests/test_polyshape.py -> build/lib.linux-x86_64-3.8/Box2D/tests
# creating build/lib.linux-x86_64-3.8/Box2D/examples/simple
# copying library/Box2D/examples/simple/__init__.py -> build/lib.linux-x86_64-3.8/Box2D/examples/simple
# copying library/Box2D/examples/simple/simple_01.py -> build/lib.linux-x86_64-3.8/Box2D/examples/simple
# copying library/Box2D/examples/simple/simple_02.py -> build/lib.linux-x86_64-3.8/Box2D/examples/simple
# creating build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/opencv_draw.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/pyqt4_framework.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/__init__.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/pyqt4_gui.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/pyglet_framework.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/pygame_gui.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/simple_framework.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/opencv_framework.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# copying library/Box2D/examples/backends/pygame_framework.py -> build/lib.linux-x86_64-3.8/Box2D/examples/backends
# creating build/lib.linux-x86_64-3.8/Box2D/examples/opencv
# copying library/Box2D/examples/opencv/triangulate_seidel.py -> build/lib.linux-x86_64-3.8/Box2D/examples/opencv
# copying library/Box2D/examples/opencv/__init__.py -> build/lib.linux-x86_64-3.8/Box2D/examples/opencv
# copying library/Box2D/examples/opencv/test_cv.py -> build/lib.linux-x86_64-3.8/Box2D/examples/opencv
# creating build/lib.linux-x86_64-3.8/Box2D/examples/pgu
# copying library/Box2D/examples/pgu/__init__.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu
# creating build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/container.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/deprecated.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/input.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/area.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/widget.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/layout.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/select.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/theme.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/__init__.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/button.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/pguglobals.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/style.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/app.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/form.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/dialog.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/slider.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/basic.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/table.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/surface.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/menus.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/textarea.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/keysym.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/document.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/const.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/group.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# copying library/Box2D/examples/pgu/gui/misc.py -> build/lib.linux-x86_64-3.8/Box2D/examples/pgu/gui
# running egg_info
# creating library/Box2D.egg-info
# writing library/Box2D.egg-info/PKG-INFO
# writing dependency_links to library/Box2D.egg-info/dependency_links.txt
# writing top-level names to library/Box2D.egg-info/top_level.txt
# writing manifest file 'library/Box2D.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'library/Box2D.egg-info/SOURCES.txt'
# creating build/lib.linux-x86_64-3.8/Box2D/examples/data
# creating build/lib.linux-x86_64-3.8/Box2D/examples/data/themes
# creating build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/Vera.ttf -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/box.down.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/box.hover.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/box.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/box.xcf -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/button.down.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/button.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/button.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/check.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/checkbox.off.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/checkbox.off.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/checkbox.on.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/checkbox.on.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/config.txt -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/console.input.focus.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/console.input.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/console.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/desktop.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/desktop.xcf -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dialog.bar.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dialog.close.down.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dialog.close.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dialog.close.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dialog.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dot.down.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dot.hover.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dot.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/dot.xcf -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/down.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/filebrowser.folder.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/generate.py -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/hslider.bar.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/hslider.bar.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/hslider.left.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/hslider.right.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/hslider.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/idot.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/input.focus.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/input.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/left.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/list.item.down.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/list.item.hover.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/list.item.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/list.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/listitem.down.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/listitem.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/listitem.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/menu.down.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/menu.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/menu.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/notes.txt -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/out.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/progressbar.bar.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/progressbar.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/radio.off.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/radio.off.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/radio.on.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/radio.on.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/radio.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/rdot.down.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/rdot.hover.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/rdot.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/right.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/sbox.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/scroller.slide.bar.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/scroller.slide.bar.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/scroller.slide.h.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/scroller.slide.v.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.arrow.down.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.arrow.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.arrow.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.arrow.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.option.hover.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.option.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.options.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.selected.down.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.selected.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/select.selected.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/slider.bar.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/slider.bar.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/slider.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/tool.down.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/tool.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/tool.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/up.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vbox.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vdot.down.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vdot.hover.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vdot.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vsbox.normal.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vslider.bar.hover.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vslider.bar.normal.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vslider.down.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vslider.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/vslider.up.tga -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# copying library/Box2D/examples/data/themes/default/x.png -> build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/default
# creating build/lib.linux-x86_64-3.8/Box2D/examples/data/themes/gray
# ...
#      ^~
# Box2D/Box2D_wrap.cpp:6328:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_1; return _wrap_b2Vec2_cross__SWIG_0(self, argc, argv);}  check_1: if (argc == 2) {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp: In function ‘PyObject* _wrap_b2Mat22___mul__(PyObject*, PyObject*)’:
# Box2D/Box2D_wrap.cpp:7105:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_1; return _wrap_b2Mat22___mul____SWIG_0(self, argc, argv);}  check_1: if (argc == 2) {
#      ^~
# Box2D/Box2D_wrap.cpp:7105:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_1; return _wrap_b2Mat22___mul____SWIG_0(self, argc, argv);}  check_1: if (argc == 2) {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp: In function ‘PyObject* _wrap_b2Dot(PyObject*, PyObject*)’:
# Box2D/Box2D_wrap.cpp:8103:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_1; { { _v = (PySequence_Check(argv[1]) ||
#      ^~
# Box2D/Box2D_wrap.cpp:8103:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_1; { { _v = (PySequence_Check(argv[1]) ||
#                             ^
# Box2D/Box2D_wrap.cpp: In function ‘PyObject* _wrap_b2Cross(PyObject*, PyObject*)’:
# Box2D/Box2D_wrap.cpp:8139:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_1; { { _v = (PySequence_Check(argv[1]) ||
#      ^~
# Box2D/Box2D_wrap.cpp:8139:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_1; { { _v = (PySequence_Check(argv[1]) ||
#                             ^
# Box2D/Box2D_wrap.cpp:8143:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_2; { { int res = SWIG_AsVal_float(argv[1], NULL); _v = SWIG_CheckState(res); } }  if (!_v) goto check_2;
#      ^~
# Box2D/Box2D_wrap.cpp:8143:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_2; { { int res = SWIG_AsVal_float(argv[1], NULL); _v = SWIG_CheckState(res); } }  if (!_v) goto check_2;
#                             ^
# Box2D/Box2D_wrap.cpp:8146:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_3; { { _v = (PySequence_Check(argv[1]) ||
#      ^~
# Box2D/Box2D_wrap.cpp:8146:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_3; { { _v = (PySequence_Check(argv[1]) ||
#                             ^
# Box2D/Box2D_wrap.cpp: In function ‘PyObject* _wrap_b2Mul(PyObject*, PyObject*)’:
# Box2D/Box2D_wrap.cpp:8356:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_1; return _wrap_b2Mul__SWIG_0(self, argc, argv);}  check_1: if (argc == 2) { int _v = 0; {
#      ^~
# Box2D/Box2D_wrap.cpp:8356:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_1; return _wrap_b2Mul__SWIG_0(self, argc, argv);}  check_1: if (argc == 2) { int _v = 0; {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp:8362:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_3; return _wrap_b2Mul__SWIG_2(self, argc, argv);}  check_3: if (argc == 2) { int _v = 0; {
#      ^~
# Box2D/Box2D_wrap.cpp:8362:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_3; return _wrap_b2Mul__SWIG_2(self, argc, argv);}  check_3: if (argc == 2) { int _v = 0; {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp:8368:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_5; return _wrap_b2Mul__SWIG_4(self, argc, argv);}  check_5: if (argc == 2) { int _v = 0; { {
#      ^~
# Box2D/Box2D_wrap.cpp:8368:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_5; return _wrap_b2Mul__SWIG_4(self, argc, argv);}  check_5: if (argc == 2) { int _v = 0; { {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp:8370:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_6; return _wrap_b2Mul__SWIG_5(self, argc, argv);}  check_6: if (argc == 2) {
#      ^~
# Box2D/Box2D_wrap.cpp:8370:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_6; return _wrap_b2Mul__SWIG_5(self, argc, argv);}  check_6: if (argc == 2) {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp: In function ‘PyObject* _wrap_b2MulT(PyObject*, PyObject*)’:
# Box2D/Box2D_wrap.cpp:8398:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_1; return _wrap_b2MulT__SWIG_0(self, argc, argv);}  check_1: if (argc == 2) { int _v = 0; {
#      ^~
# Box2D/Box2D_wrap.cpp:8398:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_1; return _wrap_b2MulT__SWIG_0(self, argc, argv);}  check_1: if (argc == 2) { int _v = 0; {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp:8407:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_4; return _wrap_b2MulT__SWIG_3(self, argc, argv);}  check_4: if (argc == 2) { int _v = 0; { {
#      ^~
# Box2D/Box2D_wrap.cpp:8407:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_4; return _wrap_b2MulT__SWIG_3(self, argc, argv);}  check_4: if (argc == 2) { int _v = 0; { {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp:8409:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_5; return _wrap_b2MulT__SWIG_4(self, argc, argv);}  check_5: if (argc == 2) {
#      ^~
# Box2D/Box2D_wrap.cpp:8409:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_5; return _wrap_b2MulT__SWIG_4(self, argc, argv);}  check_5: if (argc == 2) {
#                             ^~~~~~
# Box2D/Box2D_wrap.cpp: In function ‘PyObject* _wrap_b2Abs(PyObject*, PyObject*)’:
# Box2D/Box2D_wrap.cpp:8444:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if (!_v) goto check_1; return _wrap_b2Abs__SWIG_1(self, argc, argv);}  check_1: if (argc == 1) {
#      ^~
# Box2D/Box2D_wrap.cpp:8444:28: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if (!_v) goto check_1; return _wrap_b2Abs__SWIG_1(self, argc, argv);}  check_1: if (argc == 1) {
#                             ^~~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp: In member function ‘bool b2ContactSolver::SolvePositionConstraints()’:
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:713:51: warning: ‘psm.b2PositionSolverManifold::separation’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#     float32 C = b2Clamp(b2_baumgarte * (separation + b2_linearSlop), -b2_maxLinearCorrection, 0.0f);
#                                        ~~~~~~~~~~~~^~~~~~~~~~~~~~~~
# In file included from ./Box2D/Dynamics/Contacts/b2ContactSolver.h:22:0,
#                  from Box2D/Dynamics/Contacts/b2ContactSolver.cpp:19:
# ./Box2D/Common/b2Math.h:465:9: warning: ‘*((void*)& psm +12)’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   return b2Vec2(a.x - b.x, a.y - b.y);
#          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:699:29: note: ‘*((void*)& psm +12)’ was declared here
#     b2PositionSolverManifold psm;
#                              ^~~
# In file included from ./Box2D/Dynamics/Contacts/b2ContactSolver.h:22:0,
#                  from Box2D/Dynamics/Contacts/b2ContactSolver.cpp:19:
# ./Box2D/Common/b2Math.h:465:9: warning: ‘*((void*)& psm +8)’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   return b2Vec2(a.x - b.x, a.y - b.y);
#          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:699:29: note: ‘*((void*)& psm +8)’ was declared here
#     b2PositionSolverManifold psm;
#                              ^~~
# In file included from ./Box2D/Dynamics/Contacts/b2ContactSolver.h:22:0,
#                  from Box2D/Dynamics/Contacts/b2ContactSolver.cpp:19:
# ./Box2D/Common/b2Math.h:425:13: warning: ‘psm.b2Vec2::y’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   return a.x * b.y - a.y * b.x;
#          ~~~~^~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:699:29: note: ‘psm.b2Vec2::y’ was declared here
#     b2PositionSolverManifold psm;
#                              ^~~
# In file included from ./Box2D/Dynamics/Contacts/b2ContactSolver.h:22:0,
#                  from Box2D/Dynamics/Contacts/b2ContactSolver.cpp:19:
# ./Box2D/Common/b2Math.h:425:25: warning: ‘psm.b2Vec2::x’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   return a.x * b.y - a.y * b.x;
#                      ~~~~^~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:699:29: note: ‘psm.b2Vec2::x’ was declared here
#     b2PositionSolverManifold psm;
#                              ^~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp: In member function ‘bool b2ContactSolver::SolveTOIPositionConstraints(int32, int32)’:
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:804:53: warning: ‘psm.b2PositionSolverManifold::separation’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#     float32 C = b2Clamp(b2_toiBaugarte * (separation + b2_linearSlop), -b2_maxLinearCorrection, 0.0f);
#                                          ~~~~~~~~~~~~^~~~~~~~~~~~~~~~
# In file included from ./Box2D/Dynamics/Contacts/b2ContactSolver.h:22:0,
#                  from Box2D/Dynamics/Contacts/b2ContactSolver.cpp:19:
# ./Box2D/Common/b2Math.h:465:9: warning: ‘*((void*)& psm +12)’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   return b2Vec2(a.x - b.x, a.y - b.y);
#          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:790:29: note: ‘*((void*)& psm +12)’ was declared here
#     b2PositionSolverManifold psm;
#                              ^~~
# In file included from ./Box2D/Dynamics/Contacts/b2ContactSolver.h:22:0,
#                  from Box2D/Dynamics/Contacts/b2ContactSolver.cpp:19:
# ./Box2D/Common/b2Math.h:465:9: warning: ‘*((void*)& psm +8)’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   return b2Vec2(a.x - b.x, a.y - b.y);
#          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:790:29: note: ‘*((void*)& psm +8)’ was declared here
#     b2PositionSolverManifold psm;
#                              ^~~
# In file included from ./Box2D/Dynamics/Contacts/b2ContactSolver.h:22:0,
#                  from Box2D/Dynamics/Contacts/b2ContactSolver.cpp:19:
# ./Box2D/Common/b2Math.h:425:13: warning: ‘psm.b2Vec2::y’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   return a.x * b.y - a.y * b.x;
#          ~~~~^~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:790:29: note: ‘psm.b2Vec2::y’ was declared here
#     b2PositionSolverManifold psm;
#                              ^~~
# In file included from ./Box2D/Dynamics/Contacts/b2ContactSolver.h:22:0,
#                  from Box2D/Dynamics/Contacts/b2ContactSolver.cpp:19:
# ./Box2D/Common/b2Math.h:425:25: warning: ‘psm.b2Vec2::x’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   return a.x * b.y - a.y * b.x;
#                      ~~~~^~~~~
# Box2D/Dynamics/Contacts/b2ContactSolver.cpp:790:29: note: ‘psm.b2Vec2::x’ was declared here
#     b2PositionSolverManifold psm;
#                              ^~~
# In file included from ./Box2D/Common/b2StackAllocator.h:22:0,
#                  from Box2D/Common/b2StackAllocator.cpp:19:
# Box2D/Common/b2StackAllocator.cpp: In destructor ‘b2StackAllocator::~b2StackAllocator()’:
# ./Box2D/Common/b2Settings.h:31:100: warning: throw will always call terminate() [-Wterminate]
#  #define b2Assert(A) if (!(A)) { PyErr_SetString(PyExc_AssertionError, #A); throw b2AssertException(); }
#                                                                                                     ^
# Box2D/Common/b2StackAllocator.cpp:32:2: note: in expansion of macro ‘b2Assert’
#   b2Assert(m_index == 0);
#   ^~~~~~~~
# ./Box2D/Common/b2Settings.h:31:100: note: in C++11 destructors default to noexcept
#  #define b2Assert(A) if (!(A)) { PyErr_SetString(PyExc_AssertionError, #A); throw b2AssertException(); }
#                                                                                                     ^
# Box2D/Common/b2StackAllocator.cpp:32:2: note: in expansion of macro ‘b2Assert’
#   b2Assert(m_index == 0);
#   ^~~~~~~~
# ./Box2D/Common/b2Settings.h:31:100: warning: throw will always call terminate() [-Wterminate]
#  #define b2Assert(A) if (!(A)) { PyErr_SetString(PyExc_AssertionError, #A); throw b2AssertException(); }
#                                                                                                     ^
# Box2D/Common/b2StackAllocator.cpp:33:2: note: in expansion of macro ‘b2Assert’
#   b2Assert(m_entryCount == 0);
#   ^~~~~~~~
# ./Box2D/Common/b2Settings.h:31:100: note: in C++11 destructors default to noexcept
#  #define b2Assert(A) if (!(A)) { PyErr_SetString(PyExc_AssertionError, #A); throw b2AssertException(); }
#                                                                                                     ^
# Box2D/Common/b2StackAllocator.cpp:33:2: note: in expansion of macro ‘b2Assert’
#   b2Assert(m_entryCount == 0);
#   ^~~~~~~~
# In file included from ./Box2D/Collision/b2Collision.h:22:0,
#                  from Box2D/Collision/b2TimeOfImpact.cpp:19:
# ./Box2D/Common/b2Math.h: In function ‘void b2TimeOfImpact(b2TOIOutput*, const b2TOIInput*)’:
# ./Box2D/Common/b2Math.h:591:35: warning: ‘*((void*)(& fcn)+92).b2Vec2::y’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   float32 y = (T.q.s * v.x + T.q.c * v.y) + T.p.y;
#                              ~~~~~~^~~~~
# Box2D/Collision/b2TimeOfImpact.cpp:327:24: note: ‘*((void*)(& fcn)+92).b2Vec2::y’ was declared here
#    b2SeparationFunction fcn;
#                         ^~~
# In file included from ./Box2D/Collision/b2Collision.h:22:0,
#                  from Box2D/Collision/b2TimeOfImpact.cpp:19:
# ./Box2D/Common/b2Math.h:591:21: warning: ‘*((void*)(& fcn)+92).b2Vec2::x’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#   float32 y = (T.q.s * v.x + T.q.c * v.y) + T.p.y;
#                ~~~~~~^~~~~
# Box2D/Collision/b2TimeOfImpact.cpp:327:24: note: ‘*((void*)(& fcn)+92).b2Vec2::x’ was declared here
#    b2SeparationFunction fcn;
#                         ^~~
# warning: no files found matching 'INSTALL'
# warning: no files found matching 'README'
# warning: no files found matching 'INSTALL'
# warning: no files found matching 'README'
# build/bdist.linux-x86_64/egg/Box2D/examples/opencv/triangulate_seidel.py:599: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.size is 0:
# build/bdist.linux-x86_64/egg/Box2D/examples/opencv/triangulate_seidel.py:602: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.size is 1:
# zip_safe flag not set; analyzing archive contents...
# Box2D.__pycache__.Box2D.cpython-38: module references __file__
# Box2D.__pycache__._Box2D.cpython-38: module references __file__
# Box2D.examples.pgu.gui.__pycache__.theme.cpython-38: module references __file__
# /usr/local/lib/python3.8/dist-packages/Box2D-2.3.10-py3.8-linux-x86_64.egg/Box2D/examples/opencv/triangulate_seidel.py:599: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.size is 0:
# /usr/local/lib/python3.8/dist-packages/Box2D-2.3.10-py3.8-linux-x86_64.egg/Box2D/examples/opencv/triangulate_seidel.py:602: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif self.size is 1:

# %%
import gym
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import os

# %%
os.makedirs("outputs",exist_ok=True)

DEVICE="cuda:0"
ACTION_SPACE = [0,1,2,3]
EPISODES = 1000
STEPS = 1000
GAMMA=0.99
RENDER=False

# %%
class ReinforceModel(nn.Module):
    def __init__(self,num_action,num_input):
        super(ReinforceModel,self).__init__()
        self.num_action = num_action
        self.num_input = num_input

        self.layer1 = nn.Linear(num_input,64)
        self.layer2 = nn.Linear(64,num_action)
        
    def forward(self,x):
        x = torch.tensor(x,dtype=torch.float32,device=DEVICE).unsqueeze(0)
        x = F.relu(self.layer1(x))
        actions = F.softmax(self.layer2(x))
        action = self.get_action(actions)
        log_prob_action = torch.log(actions.squeeze(0))[action]
        return action,log_prob_action
    def get_action(self,a):
        return np.random.choice(ACTION_SPACE,p=a.squeeze(0).detach().cpu().numpy())

# %%
env = gym.make("LunarLander-v2")
print(env.action_space,env.observation_space)

model = ReinforceModel(4,8).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
all_rewards =[]
best_rolling = -99999
# Out:
# Discrete(4) Box([-inf -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf], (8,), float32)

# %%
for episode in range(EPISODES):
    done=False
    state = env.reset()
    lp=[]
    a=[]
    r=[]
    d=[]
    s=[]
    for step in range(STEPS):
        if RENDER:
            env.render()
        action,log_prob = model(state)
        state,r_,done,i_ = env.step(action)
        lp.append(log_prob)
        r_ = r_ /100
        r.append(r_)
        if done:
            all_rewards.append(np.sum(r))
            
            if episode%100 ==0:
                print(f"EPISODE {episode} SCORE: {np.sum(r)} roll{pd.Series(all_rewards).tail(100).mean()}")
                # RENDER = True
                torch.save(model.state_dict(), 'outputs/last_params_cloud.ckpt')
                if pd.Series(all_rewards).tail(100).mean()>best_rolling:
                    best_rolling = pd.Series(all_rewards).tail(100).mean()
                    print("saving...")
                    torch.save(model.state_dict(), 'outputs/best_params_cloud.ckpt')
            break
 

    discounted_rewards = []

    for t in range(len(r)):
        Gt = 0 
        pw = 0
        for r_ in r[t:]:
            Gt = Gt + GAMMA**pw * r_
            pw = pw + 1
        discounted_rewards.append(Gt)
    
    discounted_rewards = np.array(discounted_rewards)

    discounted_rewards = torch.tensor(discounted_rewards,dtype=torch.float32,device=DEVICE)
    discounted_rewards = (discounted_rewards - torch.mean(discounted_rewards))/ (torch.std(discounted_rewards))
    log_prob = torch.stack(lp)
    policy_gradient = -log_prob*discounted_rewards

    model.zero_grad()
    policy_gradient.sum().backward()
    optimizer.step()
# Out:
# <ipython-input-6-2f03012c516f>:13: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   actions = F.softmax(self.layer2(x))
# EPISODE 0 SCORE: -0.5903269697615916 roll-0.5903269697615916
# saving...
# EPISODE 100 SCORE: -2.44878137999429 roll-1.8245016403182188
# EPISODE 200 SCORE: -2.124063857812482 roll-1.654876909289788
# EPISODE 300 SCORE: -0.9928783785171148 roll-1.774826514695242
# EPISODE 400 SCORE: -2.579730622205552 roll-1.5905339279840576
# EPISODE 500 SCORE: -1.433729318646151 roll-1.6722529107576118
# EPISODE 600 SCORE: -0.1894907737614624 roll-1.588587221957965
# EPISODE 700 SCORE: -0.8450540762470876 roll-1.4101841666253419
# EPISODE 800 SCORE: -1.261705157950003 roll-1.5457056372732223
# EPISODE 900 SCORE: -1.4204424974781555 roll-1.474525021950828

# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.animation as animation

font                   = cv2.FONT_HERSHEY_SIMPLEX
bottomLeftCornerOfText = (10,500)
fontScale              = 1
fontColor              = (255,255,255)
lineType               = 2

fig = plt.figure()
env = gym.make("LunarLander-v2")
print(env.action_space,env.observation_space)

model = ReinforceModel(4,8).to(DEVICE)
model.load_state_dict(torch.load("outputs/best_params_cloud.ckpt"))

model.eval()
ims = []
rewards = []
state = env.reset()

for step in range(STEPS):
    img = env.render(mode='rgb_array')
    action,log_prob = model(state)
        # print(action)
    state,reward,done,i_ = env.step(action)
    rewards.append(reward)
    # print(reward,done)
    cv2_im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    pil_im = Image.fromarray(cv2_im_rgb)

    draw = ImageDraw.Draw(pil_im)

    # Choose a font
    font = ImageFont.truetype("Roboto-Regular.ttf", 20)

    # Draw the text
    draw.text((0, 0), f"Step: {step} Action : {action} Reward: {int(reward)} Total Rewards: {int(np.sum(rewards))} done: {done}", font=font,fill="#FDFEFE")

    # Save the image
    img = cv2.cvtColor(np.array(pil_im), cv2.COLOR_RGB2BGR)
    im = plt.imshow(img, animated=True)
    ims.append([im])
    if done:
        env.close()


                
        
        break

Writer = animation.writers['pillow']
writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)
im_ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=3000,
                                    blit=True)
im_ani.save('ll_train1.gif', writer=writer)
# Out:
# Discrete(4) Box([-inf -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf], (8,), float32)
# ---------------------------------------------------------------------------
# NoSuchDisplayException                    Traceback (most recent call last)
# <ipython-input-13-c8d9ed924eeb> in <module>
#      21 state = env.reset()
#      22 for step in range(STEPS):
# ---> 23     img = env.render(mode='rgb_array')
#      24     action,log_prob = model(state)
#      25         # print(action)
#
# /usr/local/lib/python3.8/dist-packages/gym/core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# /usr/local/lib/python3.8/dist-packages/gym/envs/box2d/lunar_lander.py in render(self, mode)
#     386
#     387     def render(self, mode="human"):
# --> 388         from gym.envs.classic_control import rendering
#     389
#     390         if self.viewer is None:
#
# /usr/local/lib/python3.8/dist-packages/gym/envs/classic_control/rendering.py in <module>
#      25
#      26 try:
# ---> 27     from pyglet.gl import *
#      28 except ImportError as e:
#      29     raise ImportError(
#
# /usr/local/lib/python3.8/dist-packages/pyglet/gl/__init__.py in <module>
#     230     # trickery is for circular import
#     231     _pyglet.gl = _sys.modules[__name__]
# --> 232     import pyglet.window
#
# /usr/local/lib/python3.8/dist-packages/pyglet/window/__init__.py in <module>
#    1917 if not _is_pyglet_doc_run:
#    1918     pyglet.window = sys.modules[__name__]
# -> 1919     gl._create_shadow_window()
#
# /usr/local/lib/python3.8/dist-packages/pyglet/gl/__init__.py in _create_shadow_window()
#     204
#     205     from pyglet.window import Window
# --> 206     _shadow_window = Window(width=1, height=1, visible=False)
#     207     _shadow_window.switch_to()
#     208
#
# /usr/local/lib/python3.8/dist-packages/pyglet/window/xlib/__init__.py in __init__(self, *args, **kwargs)
#     169                     self._event_handlers[message] = func
#     170
# --> 171         super(XlibWindow, self).__init__(*args, **kwargs)
#     172
#     173         global _can_detect_autorepeat
#
# /usr/local/lib/python3.8/dist-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, file_drops, display, screen, config, context, mode)
#     589
#     590         if not display:
# --> 591             display = pyglet.canvas.get_display()
#     592
#     593         if not screen:
#
# /usr/local/lib/python3.8/dist-packages/pyglet/canvas/__init__.py in get_display()
#      92
#      93     # Otherwise, create a new display and return it.
# ---> 94     return Display()
#      95
#      96
#
# /usr/local/lib/python3.8/dist-packages/pyglet/canvas/xlib.py in __init__(self, name, x_screen)
#     121         self._display = xlib.XOpenDisplay(name)
#     122         if not self._display:
# --> 123             raise NoSuchDisplayException('Cannot connect to "%s"' % name)
#     124
#     125         screen_count = xlib.XScreenCount(self._display)
#
# NoSuchDisplayException: Cannot connect to "None"
